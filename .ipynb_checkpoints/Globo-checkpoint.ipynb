# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('http://www.globo.com/')
soup = BeautifulSoup(page.content, 'html.parser')

for link in soup.find_all(['p', 'a']):
    print(link.get_text(strip=True))
# Out:
# globo.com
# g1
# ge
# gshow
# tech
# vídeos
# Temer reúne conselho de Defesa antes da Câmara votar decreto
# Temer reúne conselho de Defesa antes da Câmara votar decreto
# Maia diz que o decreto da intervenção no RJ não pode ter emendas
# Diário Oficial publica exoneração de Sá da Secretaria de Segurança
# 18 reféns são libertados após rebelião no RJ
# 18 reféns são libertados após rebelião no RJ
# Ministro: rebeliões já estavam previstas
# País registra protestos contra nova Previdência
# País registra protestos contra nova Previdência
# RJ tem ato em frente ao Santos Dumont
# Casal abrigou atirador após morte da mãe
# Casal abrigou atirador após morte da mãe
# Trump usa massacre contra FBI e rivais
# Força-tarefa vai ao CE após morte de traficante
# Força-tarefa vai ao CE após morte de traficante
# 'Prévia do PIB' do BC indica alta de 1,04% em 2017
# 'Prévia do PIB' do BC indica alta de 1,04% em 2017
# Tarifa 'binômia' pode deixar a luz mais barata
# ...
